# %%
import requests
import json
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
CHANNEL_ID = 1293177
NUM_FRAMES = None

# %%
def update_plot(frame):
    response = requests.get(f'https://api.thingspeak.com/channels/{CHANNEL_ID}/feed.json?results=10')
    data = response.json()
    timestamps = []
    values = []
    for entry in data['feeds']:
        timestamps.append(entry['created_at'])
        values.append(float(entry['field1']))  # Assuming the data is in Field 1

    line.set_data(timestamps, values)
    ax.relim()
    ax.autoscale_view()

fig, ax = plt.subplots()
line, = ax.plot([], [], label='Live Data')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.legend()

ani = FuncAnimation(fig, update_plot, frames=NUM_FRAMES, blit=False, interval=5000)  # Update every 5 seconds
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16176\3420300975.py:20: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(fig, update_plot, frames=NUM_FRAMES, blit=False, interval=5000)  # Update every 5 seconds
# D:\anaconda\Lib\site-packages\matplotlib\animation.py:884: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
def update_plot(frame):
    response = requests.get(f'https://api.thingspeak.com/channels/{CHANNEL_ID}/feed.json?results=10')
    data = response.json()
    timestamps = []
    values = []
    for entry in data['feeds']:
        timestamps.append(entry['created_at'])
        values.append(float(entry['field1']))  # Assuming the data is in Field 1

    line.set_data(timestamps, values)
    ax.relim()
    ax.autoscale_view()

fig, ax = plt.subplots()
line, = ax.plot([], [], label='Live Data')
ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.legend()

ani = FuncAnimation(fig, update_plot, frames=NUM_FRAMES, blit=False, interval=5000)  # Update every 5 seconds

# Display the animation using a blocking statement
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16176\3590347082.py:20: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(fig, update_plot, frames=NUM_FRAMES, blit=False, interval=5000)  # Update every 5 seconds
