# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/tips.csv",sep=",")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# printing the tip dataset

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# First 5 entries of dataset

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Last 5 entries of dataset

# %%
df.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# Data needs to be cleaned , here strings need to be removed, we can do that by normalize

# %%
df1=(df-df.mean())/df.std()
# Out:
# <ipython-input-7-e609b09024e1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1=(df-df.mean())/df.std()
# <ipython-input-7-e609b09024e1>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1=(df-df.mean())/df.std()

# %% [markdown]
# Reading the normalized dataset

# %%
df1
# Out:
#      day  sex      size smoker time       tip  total_bill
# 0    NaN  NaN -0.598961    NaN  NaN -1.436993   -0.314066
# 1    NaN  NaN  0.452453    NaN  NaN -0.967217   -1.061054
# 2    NaN  NaN  0.452453    NaN  NaN  0.362610    0.137497
# 3    NaN  NaN -0.598961    NaN  NaN  0.225291    0.437416
# 4    NaN  NaN  1.503867    NaN  NaN  0.442111    0.539635
# ..   ...  ...       ...    ...  ...       ...         ...
# 239  NaN  NaN  0.452453    NaN  NaN  2.111622    1.038377
# 240  NaN  NaN -0.598961    NaN  NaN -0.721488    0.830568
# 241  NaN  NaN -0.598961    NaN  NaN -0.721488    0.323964
# 242  NaN  NaN -0.598961    NaN  NaN -0.902171   -0.220833
# 243  NaN  NaN -0.598961    NaN  NaN  0.001244   -0.112997
#
# [244 rows x 7 columns]

# %% [markdown]
# Box plot for normalised data , box plot is used to represent data in quartiles (25%,50%,75%) here box plot is formed for size , tip and total_bill with respect to its normalised values.

# %%
plt.boxplot(df1)
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1257: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1264: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1272: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1273: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef12234de70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef12234fa60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef12234e260>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ef12234f2e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef12234dd50>,
# ...
#  'means': []}

# %% [markdown]
# Linear plot between day and tip , frequencies are displayed in a linear fashion

# %%
x=df["day"]
y=df["tip"]
plt.plot(x,y)
plt.xlabel("day")
plt.ylabel("tip")

# %% [markdown]
# Scatter plot , day and tip , scatter plot uses dots to represent the values (here tips with respect to day) , we can say that on saturday most amount of tip(s) are given with some being close to 10 i.e higher monitary value , saturday also has tips spread across value more than other days.

# %%
plt.xlabel("Day",color='red')
plt.ylabel("Tip",color="magenta")
plt.scatter(x,y)

# %% [markdown]
# Bar plot represents values in rectangular bar with height representing the tip and width representing which day it is , saturday has most tips given , thursday and sunday almost equivalent , while friday being the least

# %%
plt.bar(x, y, color ='green')
# Out:
# <BarContainer object of 244 artists>

# %% [markdown]
# Here lies the scatter plot between total bill and tip ,by this scatter plot we can determine the relation between total bill and tips , the value of tips increase with increasing bills but the frequency of tips decrease , while lower the bill more the tip but less money given as tip

# %%
x=df["total_bill"]
y=df["tip"]
plt.scatter(x,y)

# %% [markdown]
# Line plot represents linear frequency of each parameter , by the graph below day/time we can say that on thursday most amount of people prefer to have a lunch in restaurants while dinner is fairly common for all the days

# %%
x=df["day"]
y=df["time"]
plt.plot(x,y)
